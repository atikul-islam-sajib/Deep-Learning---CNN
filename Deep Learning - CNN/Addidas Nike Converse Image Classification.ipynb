# %%
####### For accessing the Google Drive ########
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
####### To Unzip the file from Google Drive ########
import zipfile
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/CNN Dataset/Rice_Image_Dataset.zip", 'r')
zip_ref.extractall()
zip_ref.close()

# %%
####### Import all necessity function for Deep Learning ########
import os
import cv2
import random 
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LeakyReLU, PReLU, ELU, BatchNormalization, Dropout, Conv2D, MaxPool2D, MaxPool3D, Flatten
from tensorflow.keras.initializers import HeNormal, HeUniform, GlorotNormal, GlorotUniform
from tensorflow.keras.activations import relu, sigmoid, softmax, swish
from tensorflow.keras.regularizers import L1, L2, L1L2
from tensorflow.keras.losses import BinaryCrossentropy, CategoricalCrossentropy, SparseCategoricalCrossentropy, MSE, MAE, Huber
from tensorflow.keras.optimizers import SGD, Adagrad, Adadelta, RMSprop, Adam, Adamax, Nadam

# %%
####### This code will be labeling the Image ########
Directory_  = '/content/Rice_Image_Dataset'
categories_ = ['Arborio', 'Basmati', 'Ipsala', 'Karacadag']
data_ = []

for i in categories_:
  folderPath_ = os.path.join(Directory_, i)

  for image_ in os.listdir(folderPath_):
    withImagePath_ = os.path.join(folderPath_, image_)
    targetLabel_   = categories_.index(i)
    imageVector_   = cv2.imread(withImagePath_)
    imageVector_   = cv2.resize(imageVector_, (100, 100))
    data_.append([imageVector_, targetLabel_])
  
  print(f"{i} is done.")

###### Shuffle the dataset ######
random.shuffle(data_)
# Out:
# Arborio is done.
# Basmati is done.
# Ipsala is done.
# Karacadag is done.

# %%
###### split the data into X and y ######
X, y = [], []
for value_ in data_:
  X.append(value_[0])
  y.append(value_[1])

print(f"X shape is {len(X)}, and y shape is {len(y)}")
# Out:
# X shape is 60000, and y shape is 60000

# %%
###### Normalized the X value #######
X = X[0:3000]
y = y[0:3000]
X = np.array(X)
y = np.array(y)
X = X/255

# %%
###### Create a model #######
model = Sequential()

###### Create second Convolution Layer with 32 filters #######
model.add(Conv2D(filters = 128, kernel_size = (3, 3),activation = 'relu', input_shape = X.shape[1:]))
model.add(MaxPool2D(2, 2))
###### Create second Convolution Layer with 32 filters #######
model.add(Conv2D(filters = 128, kernel_size = (3, 3),activation = 'relu'))
model.add(MaxPool2D(2, 2))

###### flatten the model ######
model.add(Flatten())

###### Create first hidden layer with 128 neurons ######
model.add(Dense(units = 128, activation = 'relu', kernel_initializer = HeNormal()))
###### Create first hidden layer with 128 neurons ######
model.add(Dense(units = 32, activation = 'relu', kernel_initializer = HeNormal()))


###### Create an output layer ######
model.add(Dense(units = 4, activation = 'softmax'))

# %%
###### print the summary and check the trainable parameters ######
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 98, 98, 128)       3584
#
#  max_pooling2d_6 (MaxPooling  (None, 49, 49, 128)      0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 47, 47, 128)       147584
#
#  max_pooling2d_7 (MaxPooling  (None, 23, 23, 128)      0
#  2D)
#
#  flatten_3 (Flatten)         (None, 67712)             0
#
#  dense_9 (Dense)             (None, 128)               8667264
#
#  dense_10 (Dense)            (None, 32)                4128
#
#  dense_11 (Dense)            (None, 4)                 132
#
# =================================================================
# Total params: 8,822,692
# Trainable params: 8,822,692
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.model_selection import train_test_split
####### Split the dataset into train and test #######
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 42)

# %%
###### Compile the model #######
model.compile(optimizer = 'Adam', loss = SparseCategoricalCrossentropy(), metrics = ['accuracy'])

# %%
###### fit the model and run ######
history_ = model.fit(X, y, validation_split=0.30,  epochs = 20, batch_size = 128, verbose = 1)
# Out:
# Epoch 1/20
# 17/17 [==============================] - 2s 90ms/step - loss: 0.5888 - accuracy: 0.7367 - val_loss: 0.0815 - val_accuracy: 0.9722
# Epoch 2/20
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0618 - accuracy: 0.9771 - val_loss: 0.0640 - val_accuracy: 0.9733
# Epoch 3/20
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0452 - accuracy: 0.9857 - val_loss: 0.0631 - val_accuracy: 0.9767
# Epoch 4/20
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0362 - accuracy: 0.9895 - val_loss: 0.0760 - val_accuracy: 0.9756
# Epoch 5/20
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0493 - accuracy: 0.9843 - val_loss: 0.0848 - val_accuracy: 0.9711
# Epoch 6/20
# 17/17 [==============================] - 1s 66ms/step - loss: 0.0269 - accuracy: 0.9914 - val_loss: 0.0681 - val_accuracy: 0.9744
# Epoch 7/20
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0240 - accuracy: 0.9929 - val_loss: 0.0626 - val_accuracy: 0.9789
# Epoch 8/20
# 17/17 [==============================] - 1s 66ms/step - loss: 0.0215 - accuracy: 0.9933 - val_loss: 0.0974 - val_accuracy: 0.9633
# Epoch 9/20
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0258 - accuracy: 0.9910 - val_loss: 0.0676 - val_accuracy: 0.9833
# Epoch 10/20
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0169 - accuracy: 0.9938 - val_loss: 0.0718 - val_accuracy: 0.9767
# Epoch 11/20
# 17/17 [==============================] - 1s 66ms/step - loss: 0.0138 - accuracy: 0.9957 - val_loss: 0.0759 - val_accuracy: 0.9756
# Epoch 12/20
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0110 - accuracy: 0.9962 - val_loss: 0.0781 - val_accuracy: 0.9789
# Epoch 13/20
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0102 - accuracy: 0.9971 - val_loss: 0.0985 - val_accuracy: 0.9700
# Epoch 14/20
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0123 - accuracy: 0.9948 - val_loss: 0.0932 - val_accuracy: 0.9767
# Epoch 15/20
# 17/17 [==============================] - 1s 66ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.0842 - val_accuracy: 0.9778
# Epoch 16/20
# 17/17 [==============================] - 1s 66ms/step - loss: 0.0077 - accuracy: 0.9981 - val_loss: 0.0834 - val_accuracy: 0.9778
# Epoch 17/20
# 17/17 [==============================] - 1s 66ms/step - loss: 0.0039 - accuracy: 0.9990 - val_loss: 0.1010 - val_accuracy: 0.9800
# Epoch 18/20
# 17/17 [==============================] - 1s 66ms/step - loss: 0.0042 - accuracy: 0.9986 - val_loss: 0.0955 - val_accuracy: 0.9778
# Epoch 19/20
# 17/17 [==============================] - 1s 66ms/step - loss: 0.0066 - accuracy: 0.9971 - val_loss: 0.1205 - val_accuracy: 0.9767
# Epoch 20/20
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.1056 - val_accuracy: 0.9789
